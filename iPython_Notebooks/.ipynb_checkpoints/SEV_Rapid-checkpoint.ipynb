# %% [markdown]
# <h2>
# Impacts of severe climatic disturbance on the carbon uptake potential of Creosote in the SEV NWR.
# </h2>
# <h4>
# Dan J. Krofcheck, Laura Ladwig, Marcy E. Litvak, and William Pockman.
# </h4>

# %%
import gdal, ogr, osr, numpy, os
import pandas as pd
dataDir = '/home/nikko/Research/SEV_RAPID/RE_Ortho/'
shapeDir = '/home/nikko/Research/SEV_RAPID/Shapefiles/Larrea_Plots/'
outputDir = '/home/nikko/Research/SEV_RAPID/RE_VI_Output/'

# %%
# Generator function to produce file names
def files(path):
    for file in os.listdir(path):
        if os.path.isfile(os.path.join(path, file)):
            yield file

# Function to produce rasters of NDVI and NDRE from the time series of RapidEye
# TOA-DOS imagery. 
def calculate_VI(input_value_raster):
    # Open the data
    raster = gdal.Open(input_value_raster)
    
    # Parse the file name to extract the date
    fname = (input_value_raster).split('/')[6]
    geo = raster.GetGeoTransform()
    prj = raster.GetProjection()
    
    # RapidEye has 5 spectral bands, read each as an array
    # Some bands not used at this point **
    Blue = numpy.array(raster.GetRasterBand(1).ReadAsArray(), dtype = float)
    Green = numpy.array(raster.GetRasterBand(2).ReadAsArray(), dtype = float)
    Red = numpy.array(raster.GetRasterBand(3).ReadAsArray(), dtype = float)
    RedEdge = numpy.array(raster.GetRasterBand(4).ReadAsArray(), dtype = float)
    NIR = numpy.array(raster.GetRasterBand(5).ReadAsArray(), dtype = float)
    
    # Calculate the indices of interest (NDVI, and NDRE)
    NDVI = (NIR - Red) / (NIR + Red)
    NDRE = (RedEdge - Red) / (RedEdge + Red)

    # Get the dimensions from NIR band as a template for the output image shape
    [cols,rows] = NIR.shape
    
    # Specify the naming convention for output files
    outNDVI = 'NDVI_' + fname
    outNDRE = 'NDRE_' + fname
    
    # Create the file, using the information from the original file
    outdriver = gdal.GetDriverByName("GTiff")
    outndvi   = outdriver.Create(str(outputDir + outNDVI), rows, cols, 1, gdal.GDT_Float32)
    outndre   = outdriver.Create(str(outputDir + outNDRE), rows, cols, 1, gdal.GDT_Float32)

    # Write the array to the file, which is the original array in this example
    outndvi.GetRasterBand(1).WriteArray(NDVI)
    outndre.GetRasterBand(1).WriteArray(NDRE)

    # Georeference the image
    outndvi.SetGeoTransform(geo)
    outndre.SetGeoTransform(geo)

    # Write projection information
    outndvi.SetProjection(prj)
    outndre.SetProjection(prj)

# Function to produce a dictionary of raster values given a shapefile input
def zonal_stats(feat, input_zone_polygon, input_value_raster):

    # Open data
    raster = gdal.Open(input_value_raster)
    shp = ogr.Open(input_zone_polygon)
    lyr = shp.GetLayer()

    # Get raster georeference info
    transform = raster.GetGeoTransform()
    xOrigin = transform[0]
    yOrigin = transform[3]
    pixelWidth = transform[1]
    pixelHeight = transform[5]

    # Get extent of feat
    geom = feat.GetGeometryRef()
    if (geom.GetGeometryName() == 'MULTIPOLYGON'):
        count = 0
        pointsX = []; pointsY = []
        for polygon in geom:
            geomInner = geom.GetGeometryRef(count)    
            ring = geomInner.GetGeometryRef(0)
            numpoints = ring.GetPointCount()
            for p in range(numpoints):
                    lon, lat, z = ring.GetPoint(p)
                    pointsX.append(lon)
                    pointsY.append(lat)    
            count += 1
    elif (geom.GetGeometryName() == 'POLYGON'):
        ring = geom.GetGeometryRef(0)
        numpoints = ring.GetPointCount()
        pointsX = []; pointsY = []
        for p in range(numpoints):
                lon, lat, z = ring.GetPoint(p)
                pointsX.append(lon)
                pointsY.append(lat)

    else:
        sys.exit()

    xmin = min(pointsX)
    xmax = max(pointsX)
    ymin = min(pointsY)
    ymax = max(pointsY)

    # Specify offset and rows and columns to read
    xoff = int((xmin - xOrigin)/pixelWidth)
    yoff = int((yOrigin - ymax)/pixelWidth)
    xcount = int((xmax - xmin)/pixelWidth)+1
    ycount = int((ymax - ymin)/pixelWidth)+1

    # Create memory target raster
    target_ds = gdal.GetDriverByName('MEM').Create('', xcount, ycount, gdal.GDT_Byte)
    target_ds.SetGeoTransform((
        xmin, pixelWidth, 0,
        ymax, 0, pixelHeight,
    ))

    # Create for target raster the same projection as for the value raster
    raster_srs = osr.SpatialReference()
    raster_srs.ImportFromWkt(raster.GetProjectionRef())
    target_ds.SetProjection(raster_srs.ExportToWkt())

    # Rasterize zone polygon to raster
    gdal.RasterizeLayer(target_ds, [1], lyr, burn_values=[1])

    # Read raster as arrays
    banddataraster = raster.GetRasterBand(1)
    dataraster = banddataraster.ReadAsArray(xoff, yoff, xcount, ycount).astype(numpy.float)

    bandmask = target_ds.GetRasterBand(1)
    datamask = bandmask.ReadAsArray(0, 0, xcount, ycount).astype(numpy.float)

    # Mask zone of raster
    zoneraster = numpy.ma.masked_array(dataraster,  numpy.logical_not(datamask))
    subplotname = feat.GetField("Shrub_Code")
    plotname = feat.GetField("PLOT_CODE")

    # Calculate statistics of zonal raster
    return numpy.mean(zoneraster), subplotname, plotname


# Helper function to loop through the zonal stats function
# specifically, this function loops through each feature within the
# input shapefile
def loop_zonal_stats(input_zone_polygon, input_value_raster):

    shp = ogr.Open(input_zone_polygon)
    lyr = shp.GetLayer()
    featList = range(lyr.GetFeatureCount())
    statDict = {}
    for FID in featList:
        feat = lyr.GetFeature(FID)
        meanValue = zonal_stats(feat, input_zone_polygon, input_value_raster)
        statDict[FID] = meanValue
    return statDict

# %%
test = files(dataDir)

for file in test:
    name = file
    calculate_VI(dataDir + name)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-86-778a4b517fc4> in <module>()
#       3 for file in test:
#       4     name = file
# ----> 5     calculate_VI(dataDir + name)
#
# <ipython-input-85-1f938fab83c7> in calculate_VI(input_value_raster)
#      21     Green = numpy.array(raster.GetRasterBand(2).ReadAsArray(), dtype = float)
#      22     Red = numpy.array(raster.GetRasterBand(3).ReadAsArray(), dtype = float)
# ---> 23     RedEdge = numpy.array(raster.GetRasterBand(4).ReadAsArray(), dtype = float)
#      24     NIR = numpy.array(raster.GetRasterBand(5).ReadAsArray(), dtype = float)
#      25
#
# /usr/lib/python2.7/dist-packages/osgeo/gdal.pyc in ReadAsArray(self, xoff, yoff, win_xsize, win_ysize, buf_xsize, buf_ysize, buf_obj)
#    1084         return gdalnumeric.BandReadAsArray( self, xoff, yoff,
#    1085                                             win_xsize, win_ysize,
# -> 1086                                             buf_xsize, buf_ysize, buf_obj )
#    1087
#    1088     def WriteArray(self, array, xoff=0, yoff=0):
#
# /usr/lib/python2.7/dist-packages/osgeo/gdal_array.pyc in BandReadAsArray(band, xoff, yoff, win_xsize, win_ysize, buf_xsize, buf_ysize, buf_obj)
#     231         ar = numpy.empty([buf_ysize,buf_xsize], dtype = typecode)
#     232         if BandRasterIONumPy( band, 0, xoff, yoff, win_xsize, win_ysize,
# --> 233                                 ar, datatype ) != 0:
#     234             return None
#     235
#
# /usr/lib/python2.7/dist-packages/osgeo/gdal_array.pyc in BandRasterIONumPy(*args, **kwargs)
#      80         int buf_type) -> CPLErr
#      81     """
# ---> 82   return _gdal_array.BandRasterIONumPy(*args, **kwargs)
#      83 import numpy
#      84 import _gdal_array
#
# KeyboardInterrupt:

# %%
filelist = []
d = {}
dlist = []
check = files(outputDir)
for names in check:
    filelist.append(names)
    
for names in filelist:
    name = names
    index = (name).split('_')[0]
    date = (name).split('_')[1].split('.')[0]
    imgname = outputDir + name
    shapename = shapeDir + 'allLarrea_byplot_reproj.shp'
    for subplot in arange(0,12):
        d=dict(filename = name,INDEX = index,date = date,
          VI = loop_zonal_stats(shapename, imgname)[subplot][0],
          plot = loop_zonal_stats(shapename, imgname)[subplot][1],
          subplot = loop_zonal_stats(shapename, imgname)[subplot][2],)
        dlist.append(d)

# %%
import csv
toCSV = dlist
keys = toCSV[0].keys()
with open('SevRapid_VI.csv', 'wb') as output_file:
    dict_writer = csv.DictWriter(output_file, keys)
    dict_writer.writeheader()
    dict_writer.writerows(toCSV)

# %%
VI_dataname = '/home/nikko/Research/SEV_RAPID/' + 'SevRapid_Combined.csv'
RE_VI = pd.read_csv(VI_dataname, delimiter=',')
RE_VI.index = pd.to_datetime(RE_VI.date)

RE_VI.head()
# Out:
#             Combined subplot plot INDEX        date
# date
# 2012-08-20 -0.391829     ET2   ET  NDRE  2012-08-20
# 2012-08-20 -0.026833     5P5   5P  NDRE  2012-08-20
# 2012-08-20 -0.332812     5P1   5P  NDRE  2012-08-20
# 2012-08-20 -0.273534     5P2   5P  NDRE  2012-08-20
# 2012-08-20 -0.362900     ET1   ET  NDRE  2012-08-20

# %%
for subplot in unique(RE_VI.subplot):
    toPlot = RE_VI[RE_VI.subplot == subplot]
    toPlot.Combined.plot(kind = 'bar')
plotmeans.head()
# Out:
#             Combined subplot plot INDEX        date
# date
# 2012-08-20 -0.439912     ST1   ST  NDRE  2012-08-20
# 2011-07-04 -0.086403     ST1   ST  NDRE  2011-07-04
# 2013-02-15  0.195855     ST1   ST  NDRE  2013-02-15
# 2011-09-18  2.547149     ST1   ST  NDVI  2011-09-18
# 2013-05-20 -2.391093     ST1   ST  NDVI  2013-05-20

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1,4, sharey = True, figsize = (18,4))
subplots_adjust(wspace = .1)
axs = fig.axes
idx = 0

for aplot in unique(RE_VI['plot']):
    ax = axs[idx]
    toPlot = RE_VI[RE_VI['plot'] == aplot]
    plotmeans = toPlot.groupby(['date','plot'])

    plotmeans.Combined.mean().plot(ax = ax, label = aplot)
    plotmeans.Combined.mean().plot(ax = ax, label = aplot, kind = 'bar')

    ax.legend()
    plt.setp(ax.get_xticklabels(), rotation=45)
    idx = idx + 1
